# %% [markdown]
# #Bronze Layer

# %%
df = spark.read.csv(
    path="/Volumes/dev_cagtalog/default/retail_staging/customers/customers.csv",
    header=True,
    inferSchema=True,
).write.format("delta").mode("overwrite").saveAsTable("dev_cagtalog.bronze.customers1")

# %%
spark.read.table("dev_cagtalog.bronze.customers1").display()
