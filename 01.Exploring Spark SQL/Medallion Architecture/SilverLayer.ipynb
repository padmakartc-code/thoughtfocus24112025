# %% [markdown]
# #Silver Layer

# %%
from pyspark.sql.functions import col
 
spark.read.table("dev_cagtalog.bronze.customers1").filter(
    col("CustomerName").isNotNull()
).write.mode("append").saveAsTable("dev_cagtalog.silver.customers1")
