# %%
print("Child Notebook 01")

# %%
rtv = dbutils.widgets.dropdown(name="environment",
                         defaultValue="dev",
                         choices=["dev", "test", "prod"],
                         label="Environment Type")

# %%
rtv = f"SELECTED - {dbutils.widgets.get('environment')}"

# %%
dbutils.notebook.exit(rtv)
