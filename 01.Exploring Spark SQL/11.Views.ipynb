# %% [markdown]
# #Prerequisites

# %% [markdown]
# ##Load employee.csv into dataframe

# %%
df = spark.read.csv(
    path = "/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/employee.csv",
                    sep = '|',
                    header = True,
                    inferSchema = True,
                    quote = "'"
).limit(10)

df.printSchema()
display(df)

# %% [markdown]
# #Views

# %% [markdown]
# ## Temp View

# %%
df.createTempView("user_temp_vw")

# %%
# %sql

select * from user_temp_vw;

# %%
for view in spark.catalog.listTables();

# %% [markdown]
# ## Global View

# %%
df.createGlobalTempView("user_glb_vw")
