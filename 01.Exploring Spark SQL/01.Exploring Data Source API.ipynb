# %%
dfr=spark.read
print(type(dfr))

# %%
print("Welcome to Databricks Training Programme")

# %% [markdown]
# #Create DataFrame from Different data sources

# %% [markdown]
# # Create DataFrame from CSV File

# %%
df = dfr.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    inferSchema=True
)
df.display()

# %% [markdown]
# #Create a DataFrame from Delimited FIle

# %%
df = dfr.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",
    header=True,
    inferSchema=True,
    sep="|"
    )
df.display()

# %% [markdown]
# #Create a Datafrom Json file

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.json"
)
df.display()

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_002.json",
    multiLine=True,
).display()

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_003.json"
)
multiline=True
df.display()

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json",
    multiLine=True,
).display()

# %% [markdown]
# #Custom Schema

# %%
from pyspark.sql.types import *
 
USER_SCHEMA = StructType(
    [
        StructField("id", IntegerType()),
        StructField("age", IntegerType()),
        StructField("gen", StringType()),
        StructField("designation", StringType()),
        StructField("salary", IntegerType()),
    ]
)
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    schema=USER_SCHEMA
)
df.printSchema()
df.display()

# %% [markdown]
# #Handling Bad Records
#
# 1.PERMISSIVE(default)
#
# 2.DROPMALFORMED
#
# 3.FAILFAST

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json").display(),
mode="PERMISSIVE"

# %%
spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
mode="DROPMALFORMED").display()

# %% [markdown]
# #DataFrame Writer API

# %% [markdown]
# #Convert CSV into JSON

# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
print(type(df.write))
df.write.save(
    format="JSON",
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json",
    mode="overwrite"
)

# %%
spark.read.json(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json"
).show()

# %% [markdown]
# #Output Modes

# %% [markdown]
# ## errorifexists

# %% [markdown]
# ##overwrite

# %%
df.write.save(
    format="JSON",
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json",
    mode="Overwrite"
)

# %% [markdown]
# ##append

# %%
df.write.save(
    format="JSON",
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json",
    mode="append"
)

# %% [markdown]
# ##ignore

# %%
df.write.save(
    format="JSON",
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_json",
    mode="ignore"
)
